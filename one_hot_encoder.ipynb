# %%
import numpy as np
import pandas as pd
path = "/Users/nikita_agarwal/Desktop/sqlite/Semester project/CO2_Canada.csv"
 
Dataset = pd.read_csv(path)

# %%
Dataset.head
# Out:
# <bound method NDFrame.head of        Make        Model   Vehicle Class  Engine Size(L)  Cylinders  \
# 0     ACURA          ILX         COMPACT             2.0          4
# 1     ACURA          ILX         COMPACT             2.4          4
# 2     ACURA   ILX HYBRID         COMPACT             1.5          4
# 3     ACURA      MDX 4WD     SUV - SMALL             3.5          6
# 4     ACURA      RDX AWD     SUV - SMALL             3.5          6
# ...     ...          ...             ...             ...        ...
# 7380  VOLVO  XC40 T5 AWD     SUV - SMALL             2.0          4
# 7381  VOLVO  XC60 T5 AWD     SUV - SMALL             2.0          4
# 7382  VOLVO  XC60 T6 AWD     SUV - SMALL             2.0          4
# 7383  VOLVO  XC90 T5 AWD  SUV - STANDARD             2.0          4
# 7384  VOLVO  XC90 T6 AWD  SUV - STANDARD             2.0          4
#
#      Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# ...

# %%
Dataset.describe()
# Out:
#        Engine Size(L)    Cylinders  Fuel Consumption City (L/100 km)  \
# count     7385.000000  7385.000000                       7385.000000
# mean         3.160068     5.615030                         12.556534
# std          1.354170     1.828307                          3.500274
# min          0.900000     3.000000                          4.200000
# 25%          2.000000     4.000000                         10.100000
# 50%          3.000000     6.000000                         12.100000
# 75%          3.700000     6.000000                         14.600000
# max          8.400000    16.000000                         30.600000
#
#        Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# count                      7385.000000                       7385.000000
# mean                          9.041706                         10.975071
# std                           2.224456                          2.892506
# ...

# %%
Dataset.dtypes
# Out:
# Make                                 object
# Model                                object
# Vehicle Class                        object
# Engine Size(L)                      float64
# Cylinders                             int64
# Transmission                         object
# Fuel Type                            object
# Fuel Consumption City (L/100 km)    float64
# Fuel Consumption Hwy (L/100 km)     float64
# Fuel Consumption Comb (L/100 km)    float64
# Fuel Consumption Comb (mpg)           int64
# CO2 Emissions(g/km)                   int64
# dtype: object

# %%
# COLLECTING ALL THE DATA TOGETHER HAVING DATATYPE AS OBJECT
obj_df = Dataset.select_dtypes(include=['object']).copy()
obj_df.head()
# Out:
#     Make       Model Vehicle Class Transmission Fuel Type
# 0  ACURA         ILX       COMPACT          AS5         Z
# 1  ACURA         ILX       COMPACT           M6         Z
# 2  ACURA  ILX HYBRID       COMPACT          AV7         Z
# 3  ACURA     MDX 4WD   SUV - SMALL          AS6         Z
# 4  ACURA     RDX AWD   SUV - SMALL          AS6         Z

# %%
# CONVERTING DATATYPE OF "FUEL TYPE" AS CATEGORY
Dataset["Fuel Type"] = Dataset["Fuel Type"].astype('category')
Dataset.dtypes
# Out:
# Make                                  object
# Model                                 object
# Vehicle Class                         object
# Engine Size(L)                       float64
# Cylinders                              int64
# Transmission                          object
# Fuel Type                           category
# Fuel Consumption City (L/100 km)     float64
# Fuel Consumption Hwy (L/100 km)      float64
# Fuel Consumption Comb (L/100 km)     float64
# Fuel Consumption Comb (mpg)            int64
# CO2 Emissions(g/km)                    int64
# dtype: object

# %%
#Then  assign the encoded variable to a new column using 
#the cat.codes accessor:
Dataset["Fuel Type"] = Dataset["Fuel Type"].cat.codes

# %%
Dataset.head(10)
# Out:
#     Make       Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0  ACURA         ILX       COMPACT             2.0          4          AS5
# 1  ACURA         ILX       COMPACT             2.4          4           M6
# 2  ACURA  ILX HYBRID       COMPACT             1.5          4          AV7
# 3  ACURA     MDX 4WD   SUV - SMALL             3.5          6          AS6
# 4  ACURA     RDX AWD   SUV - SMALL             3.5          6          AS6
# 5  ACURA         RLX      MID-SIZE             3.5          6          AS6
# 6  ACURA          TL      MID-SIZE             3.5          6          AS6
# 7  ACURA      TL AWD      MID-SIZE             3.7          6          AS6
# 8  ACURA      TL AWD      MID-SIZE             3.7          6           M6
# 9  ACURA         TSX       COMPACT             2.4          4          AS5
#
#    Fuel Type  Fuel Consumption City (L/100 km)  \
# 0          4                               9.9
# ...

# %%
# OrdinalEncoder TO COVERT MAKE INTO NUMERICAL VALUES
from sklearn.preprocessing import OrdinalEncoder

ord_enc = OrdinalEncoder()
Dataset["Make"] = ord_enc.fit_transform(Dataset[["Make"]])

# %%
#OrdinalEncoder TO COVERT MODEL INTO NUMERICAL VALUES
from sklearn.preprocessing import OrdinalEncoder

ord_enc = OrdinalEncoder()
Dataset["Model"] = ord_enc.fit_transform(Dataset[["Model"]])
Dataset.head(10)
# Out:
#    Make   Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0   0.0  1056.0       COMPACT             2.0          4          AS5
# 1   0.0  1056.0       COMPACT             2.4          4           M6
# 2   0.0  1057.0       COMPACT             1.5          4          AV7
# 3   0.0  1232.0   SUV - SMALL             3.5          6          AS6
# 4   0.0  1498.0   SUV - SMALL             3.5          6          AS6
# 5   0.0  1509.0      MID-SIZE             3.5          6          AS6
# 6   0.0  1775.0      MID-SIZE             3.5          6          AS6
# 7   0.0  1776.0      MID-SIZE             3.7          6          AS6
# 8   0.0  1776.0      MID-SIZE             3.7          6           M6
# 9   0.0  1800.0       COMPACT             2.4          4          AS5
#
#    Fuel Type  Fuel Consumption City (L/100 km)  \
# 0          4                               9.9
# 1          4                              11.2
# 2          4                               6.0
# ...

# %%
# OrdinalEncoder TO COVERT vehicle class INTO NUMERICAL VALUES
from sklearn.preprocessing import OrdinalEncoder

ord_enc = OrdinalEncoder()
Dataset["Vehicle Class"] = ord_enc.fit_transform(Dataset[["Vehicle Class"]])
Dataset.head(10)
# Out:
#    Make   Model  Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0   0.0  1056.0            0.0             2.0          4          AS5
# 1   0.0  1056.0            0.0             2.4          4           M6
# 2   0.0  1057.0            0.0             1.5          4          AV7
# 3   0.0  1232.0           11.0             3.5          6          AS6
# 4   0.0  1498.0           11.0             3.5          6          AS6
# 5   0.0  1509.0            2.0             3.5          6          AS6
# 6   0.0  1775.0            2.0             3.5          6          AS6
# 7   0.0  1776.0            2.0             3.7          6          AS6
# 8   0.0  1776.0            2.0             3.7          6           M6
# 9   0.0  1800.0            0.0             2.4          4          AS5
#
#    Fuel Type  Fuel Consumption City (L/100 km)  \
# 0          4                               9.9
# 1          4                              11.2
# ...

# %%
# CONVERTING DATATYPE OF "Transmission" AS CATEGORY
Dataset["Transmission"] = Dataset["Transmission"].astype('category')
obj_df.dtypes
# Out:
# Make             object
# Model            object
# Vehicle Class    object
# Transmission     object
# Fuel Type        object
# dtype: object

# %%
#Then  assign the encoded variable to a new column using 
#the cat.codes accessor:
Dataset["Transmission"] = Dataset["Transmission"].cat.codes
Dataset.head(5)
# Out:
#    Make   Model  Vehicle Class  Engine Size(L)  Cylinders  Transmission  \
# 0   0.0  1056.0            0.0             2.0          4            14
# 1   0.0  1056.0            0.0             2.4          4            25
# 2   0.0  1057.0            0.0             1.5          4            22
# 3   0.0  1232.0           11.0             3.5          6            15
# 4   0.0  1498.0           11.0             3.5          6            15
#
#    Fuel Type  Fuel Consumption City (L/100 km)  \
# 0          4                               9.9
# 1          4                              11.2
# 2          4                               6.0
# 3          4                              12.7
# 4          4                              12.1
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
# 1                              7.7                               9.6
# ...

# %%
final_dataset= "/Users/nikita_agarwal/Desktop/sqlite/Semester project/CO2_Canada_final_dataset.csv"

# %%
Dataset.to_csv(final_dataset)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12,10))
cor = Dataset.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
Dataset.head(5)
# Out:
#    Make   Model  Vehicle Class  Engine Size(L)  Cylinders  Transmission  \
# 0   0.0  1056.0            0.0             2.0          4            14
# 1   0.0  1056.0            0.0             2.4          4            25
# 2   0.0  1057.0            0.0             1.5          4            22
# 3   0.0  1232.0           11.0             3.5          6            15
# 4   0.0  1498.0           11.0             3.5          6            15
#
#    Fuel Type  Fuel Consumption City (L/100 km)  \
# 0          4                               9.9
# 1          4                              11.2
# 2          4                               6.0
# 3          4                              12.7
# 4          4                              12.1
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
# 1                              7.7                               9.6
# ...

# %%
# split data
X = Dataset.drop('CO2 Emissions(g/km)',axis=1)
y = Dataset['CO2 Emissions(g/km)']

# %%
X.head(5)
# Out:
#    Make   Model  Vehicle Class  Engine Size(L)  Cylinders  Transmission  \
# 0   0.0  1056.0            0.0             2.0          4            14
# 1   0.0  1056.0            0.0             2.4          4            25
# 2   0.0  1057.0            0.0             1.5          4            22
# 3   0.0  1232.0           11.0             3.5          6            15
# 4   0.0  1498.0           11.0             3.5          6            15
#
#    Fuel Type  Fuel Consumption City (L/100 km)  \
# 0          4                               9.9
# 1          4                              11.2
# 2          4                               6.0
# 3          4                              12.7
# 4          4                              12.1
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
# 1                              7.7                               9.6
# ...

# %%
#standardise dataset-X
array=X.values
for i in range(len(X.columns)):
    mean_val = array[:,i].mean()
    std_val = array[:,i].std()
    array[:,i]= ((array[:,i] - mean_val)/std_val)

# %%
X = array

# %%
#r2 score after standardization

#X = array[:,0:11]

from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from scipy import stats
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error as MSE 
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import BayesianRidge
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20,
                                                    random_state =42)
models = []

models.append(('LR', LinearRegression()))
models.append(('R', Ridge()))
models.append(('L', Lasso()))
models.append(('BR', BayesianRidge(n_iter=1000)))
models.append(('KNR', KNeighborsRegressor()))
models.append(('DTR', DecisionTreeRegressor()))
models.append(('SVR', SVR()))
models.append(('ABR', AdaBoostRegressor(n_estimators=300)))
models.append(('BR', BaggingRegressor(n_estimators=300)))
models.append(('ETR', ExtraTreesRegressor(n_estimators=300)))
models.append(('GBR', GradientBoostingRegressor(n_estimators=300)))
models.append(('RFR', RandomForestRegressor(n_estimators=300)))

for name, model in models:
    model.fit(X_train, y_train)
    m_predict = model.predict(X_test)
    m_score = r2_score(y_test, m_predict)
    print("%s: r2_score = %.3f" % (name, m_score))
# Out:
# LR: r2_score = 0.914
# R: r2_score = 0.914
# L: r2_score = 0.913
# BR: r2_score = 0.914
# KNR: r2_score = 0.986
# DTR: r2_score = 0.992
# SVR: r2_score = 0.925
# ABR: r2_score = 0.913
# BR: r2_score = 0.998
# ETR: r2_score = 0.997
# GBR: r2_score = 0.998
# RFR: r2_score = 0.998

# %%
#pca with 3 feature

from numpy import array
from sklearn.decomposition import PCA
# create the PCA instance
pca = PCA(3)
# fit on data
pca.fit(X)
# access values and vectors
print("pca_components\n")
print(pca.components_)
print("pca_explained_variance\n")
print(pca.explained_variance_ratio_)
# transform data
B = pca.transform(X)
print(B)
# Out:
# pca_components
#
# [[-0.09423575  0.05925267  0.1300702   0.37817153  0.36406214 -0.18179831
#   -0.02219845  0.41453234  0.40227198  0.41521742 -0.3943689 ]
#  [-0.09434362  0.40588022  0.40185877 -0.20114687 -0.27214173 -0.34948721
#   -0.64726032 -0.02391122  0.08232335  0.0128068   0.04181804]
#  [-0.52038731 -0.54346182 -0.40719642  0.01093804  0.00956343 -0.40074904
#   -0.31585588  0.00673819 -0.07210093 -0.02013066  0.04257173]]
# pca_explained_variance
#
# [0.50453818 0.11633024 0.10248049]
# [[-2.06302812 -0.51818039  1.24623687]
#  [-1.51588807 -1.09725601  0.58115714]
#  [-4.21885439 -0.75974612  0.92772619]
#  ...
#  [-0.9480446   0.57756724 -2.68966522]
#  [-1.20021995  0.6686398  -2.75832834]
#  [-0.73088502  0.66351089 -2.79354204]]

# %%
#r2 score after pca

from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from scipy import stats
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error as MSE 
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import BayesianRidge
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
X_train, X_test, y_train, y_test = train_test_split(B, y, test_size = 0.20,
                                                    random_state =42)
models = []

models.append(('LR', LinearRegression()))
models.append(('R', Ridge()))
models.append(('L', Lasso()))
models.append(('BR', BayesianRidge(n_iter=1000)))
models.append(('KNR', KNeighborsRegressor()))
models.append(('DTR', DecisionTreeRegressor()))
models.append(('SVR', SVR()))
models.append(('ABR', AdaBoostRegressor(n_estimators=300)))
models.append(('BR', BaggingRegressor(n_estimators=300)))
models.append(('ETR', ExtraTreesRegressor(n_estimators=300)))
models.append(('GBR', GradientBoostingRegressor(n_estimators=300)))
models.append(('RFR', RandomForestRegressor(n_estimators=300)))

for name, model in models:
    model.fit(X_train, y_train)
    m_predict = model.predict(X_test)
    m_score = r2_score(y_test, m_predict)
    print("%s: r2_score = %.3f" % (name, m_score))
# Out:
# LR: r2_score = 0.909
# R: r2_score = 0.909
# L: r2_score = 0.908
# BR: r2_score = 0.909
# KNR: r2_score = 0.980
# DTR: r2_score = 0.968
# SVR: r2_score = 0.912
# ABR: r2_score = 0.902
# BR: r2_score = 0.979
# ETR: r2_score = 0.986
# GBR: r2_score = 0.969
# RFR: r2_score = 0.980

# %%
#predicts the CO2 emission  using Extra Tree Regressor 
ETR = ExtraTreesRegressor()
ETR.fit(X_train, y_train)

y_pred = ETR.predict(X_test)

# %%
y_test = y_test.reset_index(drop=True)
y_pred_df = pd.DataFrame({'Co2_emission_prediction': y_pred.flatten()})

# %%
#Comparing the predicted CO2 emission vs original CO2 emission by joining them
Comparison= pd.merge(y_test, y_pred_df, left_index=True, right_index=True)
Comparison.head(100)
# Out:
#     CO2 Emissions(g/km)  Co2_emission_prediction
# 0                   253               253.010000
# 1                   344               342.830000
# 2                   322               327.000000
# 3                   297               295.000000
# 4                   308               308.000000
# ..                  ...                      ...
# 95                  211               207.070000
# 96                  285               284.840000
# 97                  334               318.960000
# 98                  212               201.863333
# 99                  306               306.210000
#
# [100 rows x 2 columns]

# %%
x = 50
comparison = Comparison.head(x)
comparison.plot(kind = 'bar', figsize = (20,15))
bmw_pred = plt.grid(linestyle = '-', linewidth = '0.6', color = 'green', which = 'both')
plt.show()
